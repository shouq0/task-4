# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('happiness.csv')

# %%
df.plot(x='Mean',y='N=')
plt.show()

# %%
falvors=df[df.Mean != '-1']
falvors['Mean'].value_counts().plot.pie()
plt.legend()
plt.show()
